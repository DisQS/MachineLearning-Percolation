# %%
import numpy as np
from collections import Counter, OrderedDict
import random
import os
import binascii
import sys
import time 
import datetime

import os
os.chdir('./Data/L30')

# %%
import numpy as np
from collections import Counter, OrderedDict
import random
import os
import binascii
import sys
import time 
import datetime

np.set_printoptions(threshold=sys.maxsize)

# ###############################################################################
# percolation tool library from (hopefully) correct path
# ###############################################################################

machine= "csc"
user= "phsht"

# adding Folder_2 to the system path
#print(sys.path)

if machine!="avon":
    print("--- NOT working on avon")
    if user=="phsht":
        print(" --- working for phsht")
        #sys.path.insert(0,'../PyCode')
        sys.path.insert(0,'/storage/disqs/ML-Percolation/MachineLearning-Percolation/PyCode')
        #print(sys.path)
else:
    print("--- working on avon")
    if user=="phsht":
        print(machine, user)
        print(" --- working for phsht")
        sys.path.insert(0, '../PyCode')    

#print(sys.path)
from libPerco import *

###############################################################################
def percolation(im,p,size_sys,seed,nb_hlines,hthick,nb_vlines,vthick,nb_updlines,updthick,nb_downdlines,downdthick,typemod):

    import pickle

    # the seed has alreayd been checked to see if it's ok
    # but it also means we should only use it for im=1
    print('percolation: new percolation starting with seed=', seed)
    np.random.seed(seed)
    random.seed(seed)

    #create_directory('percolating')   #if we want to classify them inside each density directory
    #create_directory('not_percolating')
    
    for t in range(im):
        print('--- working in image', t, datetime.datetime.now())
        start2=time.time()
        lattice_para=lattice_config(size_sys,seed,p)

        
        occupied = lattice_para[0].nonzero()
        print('occupied',len(list(zip(*occupied))))
        n_clusters_pbc = 0
        n_clusters = 0
        cluster_pbc=np.zeros((size_sys,size_sys), dtype=int)-1
        cluster=np.zeros((size_sys,size_sys), dtype=int)-1
        sizes_pbc = Counter()
        sizes = Counter()
#         print('cluster')
        print("Hoshen-Kopelman PBS START", datetime.datetime.now())
        for i, j in zip(*occupied):
            if cluster_pbc[i,j] == -1:
                cluster_matrix_pbc(i, j, n_clusters_pbc, size_sys,lattice_para[0],cluster_pbc, sizes_pbc)

                n_clusters_pbc += 1
        print("Hoshen-Kopelman PBC END", datetime.datetime.now())
        
        print("Hoshen-Kopelman HW START", datetime.datetime.now())
        for i, j in zip(*occupied):
            if cluster[i,j] == -1:
                cluster_matrix(i, j, n_clusters, size_sys,lattice_para[0],cluster, sizes)

                n_clusters += 1
                #print(n_clusters)
        print("Hoshen-Kopelman HW END", datetime.datetime.now())
        
        print("PBC characterization", datetime.datetime.now())
            
        order_pbc=OrderedDict(sizes_pbc.most_common())
                  
        classification_pbc=list(order_pbc)
        #print(order)
        
        numbers_pbc = np.arange(0,n_clusters_pbc)
        weight_pbc=-np.sort(-(numbers_pbc))
        k_pbc=list(zip(classification_pbc,weight_pbc))
        
        correspondance_pbc=sorted(k_pbc, key = lambda t: t[0])
        unzip_pbc=list(zip(*correspondance_pbc))
        new_mapping_pbc=unzip_pbc[1]
        
        
        print("HW characterization", datetime.datetime.now())
        
        order=OrderedDict(sizes.most_common())
                  
        classification=list(order)
        
        
        numbers = np.arange(0,n_clusters)
        weight=-np.sort(-(numbers))
        k=list(zip(classification,weight))
        
        correspondance=sorted(k, key = lambda t: t[0])
        unzip=list(zip(*correspondance))
        
        new_mapping=unzip[1]

        print("PBC coloring", datetime.datetime.now())

        print('n clusters pbc',n_clusters_pbc)
        print('n clusters',n_clusters)
        
        # here starts the cross
        
        coord_hlines=[]
        thick_hlines=[]
        coord_vlines=[]
        thick_vlines=[]
        up_coord_dlines=[]
        up_thick_dlines=[]
        down_coord_dlines=[]
        down_thick_dlines=[]
        temp_cluster_pbc=cluster_pbc #np.zeros((size_sys,size_sys))
        temp_cluster=cluster
        if typemod>=0:
            mod=1
        if typemod<0:
            mod=-1
        #print('#################################################')
        #print('pbc before mod',temp_cluster_pbc)
        #print('hw before mod',temp_cluster)
        for hline in range(nb_hlines):
            thline=hthick
            hline=random.randint(0,(size_sys-1)-(thline-1))
                        
            coord_hlines.append(hline)
            thick_hlines.append(thline)
            
            
            #PBC -----------------------------------
            #print('PBC: len before h-line modification',len(cluster_pbc))
           # print('init',cluster_pbc)
            #print('hline',hline)
            for line in range(thline):
                temp_cluster_pbc[hline+line,:]=[mod]*len(temp_cluster_pbc[0])
                temp_cluster[hline+line,:]=[mod]*len(temp_cluster[0])
                #print('temp pbc',temp_cluster_pbc)
                #print('temp hw',temp_cluster)
            
#             print('PBC: len after h-line modification, size_blank_pbc', size_blank_pbc)
            
#             #HW -----------------------------------
#             print('HW: len before h-line modification',len(cluster))
#             print('init',cluster)
        
           
#             print('cluster_blank',cluster_blank)
#             print('HW: len after h-line modification, size_blank_pbc', size_blank)
            
        for vline in range(nb_vlines):
            tvline=vthick
            vline=random.randint(0,(size_sys-1)-(tvline-1))
            
            coord_vlines.append(vline)
            thick_vlines.append(tvline)
            #print('#######################################vline')
            #print('vline',vline)
            #PBC -----------------------------------
            #print('PBC: len before v-line modification',len(cluster_pbc))
            for line in range(tvline):
                temp_cluster_pbc[:,vline+line]=[mod]*len(temp_cluster_pbc)
                temp_cluster[:,vline+line]=[mod]*len(temp_cluster)
                #print('temp pbc',temp_cluster_pbc)
                #print('temp hw',temp_cluster)
            
       
        
        for up_dline in range(nb_updlines):
            up_tdline=updthick
            up_dline=random.randint(0,(size_sys-1)-(up_tdline-1))
            up_coord_dlines.append(up_dline)
            up_thick_dlines.append(up_tdline)
            #print('#######################################vline')
            #print('up_dline',up_dline)
            for line in range(up_tdline):
                #np.fill_diagonal(temp_cluster_pbc[:,up_dline+line:], mod)
                #np.fill_diagonal(temp_cluster[:,up_dline+line:], mod)
                temp_cluster_pbc.ravel()[up_dline+line:max(0,temp_cluster_pbc.shape[1]-up_dline+line)*temp_cluster_pbc.shape[1]:temp_cluster_pbc.shape[1]+1]=mod
                temp_cluster.ravel()[up_dline+line:max(0,temp_cluster.shape[1]-up_dline+line)*temp_cluster.shape[1]:temp_cluster.shape[1]+1]=mod
               # print('temp pbc',temp_cluster_pbc)
               # print('temp hw',temp_cluster)
        for down_dline in range(nb_downdlines):
            down_tdline=downdthick
            down_dline=random.randint(0,(size_sys-1)-(down_tdline-1))
            down_coord_dlines.append(down_dline)
            down_thick_dlines.append(down_tdline)
            #print('#######################################vline')
            #print('down_dline',down_dline)
            for line in range(down_tdline):
                #np.fill_diagonal(np.fliplr(temp_cluster_pbc[down_dline:,:]),mod)
                #np.fill_diagonal(np.fliplr(temp_cluster[down_dline:,:]),mod)
                temp_cluster_pbc.ravel()[down_dline+line:(down_dline+line)*(temp_cluster_pbc.shape[1]+1):temp_cluster_pbc.shape[1]-1]=mod
                temp_cluster.ravel()[down_dline+line:(down_dline+line)*(temp_cluster.shape[1]+1):temp_cluster.shape[1]-1]=mod
                #print('temp pbc',temp_cluster_pbc)
                #print('temp hw',temp_cluster)
        cluster_blank_pbc= temp_cluster_pbc
        cluster_blank=temp_cluster
            
#             print('cluster_blank_pbc',cluster_blank_pbc)
#             size_blank_pbc=len(cluster_blank_pbc)
#             print('PBC: len after v-line modification, size_blank_pbc', size_blank_pbc)
            
#             #HW -----------------------------------
#             print('HW: len before v-line modification',len(cluster))
            
            
            
            
            
            
            
#             print('HW: len after v-line modification, size_blank_pbc', size_blank)
        
############################################ For PBC
#        print('before pbc',len(cluster_pbc))
#        
#        cluster_pbc=np.delete(cluster_pbc,mid,1)
#        cluster_pbc=np.delete(cluster_pbc,mid,0)
#        col=np.zeros((len(cluster_pbc),thline), dtype='int')-1
#     
#        print(col)
#        print( len(cluster_pbc))
#        cluster_blank_pbc=np.c_[cluster_pbc[:,:mid],col,cluster_pbc[:,mid:]]
#        row=np.zeros((thline,len(cluster_blank_pbc[0])), dtype='int')-1
#
#        print(len(row),row)
#
#        cluster_blank_pbc=np.r_[cluster_blank_pbc[:mid,:],row,cluster_blank_pbc[mid:,:]]
#        size_blank_pbc=len(cluster_blank_pbc)
#        print('size_blank_pbc', size_blank_pbc)
#
############################################ For HW

#        print('before',len(cluster))
#        cluster=np.delete(cluster,mid,1)
#        cluster=np.delete(cluster,mid,0)
#        print( len(cluster))
#        cluster_blank=np.c_[cluster[:,:mid],col,cluster[:,mid:]]
#        row=np.zeros((thline,len(cluster_blank[0])), dtype='int')-1
#        cluster_blank=np.r_[cluster_blank[:mid,:],row,cluster_blank[mid:,:]]
#        size_blank=len(cluster_blank)
#        print('size_blank', size_blank)
################################################
        #print('mapping',new_mapping)
        cluster_blank_pbc_int= np.array([new_mapping_pbc[v]+1 \
                                         if not v == -1 else 0 for v in cluster_blank_pbc.flat]).reshape(size_sys,size_sys)
        cluster_blank_pbc_norm = np.array([(new_mapping_pbc[v]+1)/n_clusters_pbc \
                                           if not v == -1 else 0 for v in cluster_blank_pbc.flat]).reshape(size_sys,size_sys)
        cluster_blank_pbc_nan= np.array([new_mapping_pbc[v]+1 \
                                         if not v == -1 else np.nan for v in cluster_blank_pbc.flat]).reshape(size_sys,size_sys)      
        
        cluster_pbc_nan= np.array([new_mapping_pbc[v]+1 \
                            if not v == -1 else np.nan for v in cluster_pbc.flat]).reshape(size_sys,size_sys)
       # print("HW coloring", datetime.datetime.now())
        
        cluster_blank_int= np.array([new_mapping[v]+1 \
                                     if not v == -1 else 0 for v in cluster_blank.flat]).reshape(size_sys,size_sys)
        cluster_blank_norm = np.array([(new_mapping[v]+1)/n_clusters \
                                       if not v == -1 else 0 for v in cluster_blank.flat]).reshape(size_sys,size_sys)
        cluster_blank_nan = np.array([new_mapping[v]+1 \
                                      if not v == -1 else np.nan for v in cluster_blank.flat]).reshape(size_sys,size_sys)
        cluster_nan = np.array([new_mapping[v]+1\
                           if not v == -1 else np.nan for v in cluster.flat]).reshape(size_sys,size_sys)

        p1=len(list(zip(*cluster_blank_int.nonzero()))) / (size_sys**2)
        print("density change p=",p,"->",p1)
        
        all_sizes_pbc = Counter(list(sizes_pbc.values()))
        
        #get size of largest cluster
        if n_clusters_pbc !=0:
            max_size_pbc = max(all_sizes_pbc.keys())
        
        occ=len(list(zip(*cluster_blank_int.nonzero())))
        start4=time.time()
        proba_largest=(max_size_pbc/(size_sys**2))**2

        square_proba=p*p

       
        print('max clus', max_size_pbc)
        end4=time.time()-start4

        occ=len(list(zip(*cluster_blank_int.nonzero())))

        top=cluster_nan[0][:]
        bottom=cluster_nan[-1][:]
        left=cluster_nan[:,0]
        right=cluster_nan[:,-1]
       
        top_bot_inter=set(x for x in cluster_nan[0][:]).intersection(set(y for y in cluster_nan[-1][:]))
        sides_inter=set(w for w in cluster_nan[:,0]).intersection(set(z for z in cluster_nan[:,-1]))
        
        
        HWTB=0
        HWLR=0
        PBCTB=0
        PBCLR=0
        
        size_side_spanning_pbc=0
        size_top_spanning_pbc=0
        size_top_side_spanning_pbc=0
        rgba1=0
        rgba2=0
         
        if (top_bot_inter!=set() or sides_inter!=set()):
            
            top_pbc=set(x for x in cluster_pbc_nan[0][:]).intersection(set(y for y in cluster_pbc_nan[-1][:]))
            side_pbc=set(w for w in cluster_pbc_nan[:,0]).intersection(set(z for z in cluster_pbc_nan[:,-1]))
            
            union_top_side_spanning_pbc= side_pbc.union(top_pbc)
            
            
            if top_bot_inter!=0 and sides_inter!=0:
                HWTB=1
                HWLR=1
                PBCTB=pbc_percolation(top_bot_inter,top,bottom,PBCTB)
               
                
                PBCLR=pbc_percolation(sides_inter,left,right,PBCLR)
                
 
            elif top_bot_inter!=0:
                HWTB=1
                PBCTB=pbc_percolation(top_bot_inter,top,bottom,PBCTB)

  
            else:
                HWLR=1
                PBCLR=pbc_percolation(sides_inter,left,right,PBCLR)

 
   
            filename1='pc_0_1_'+str(HWTB)+'_'+str(HWLR)+'_'+str(PBCTB)+'_'+str(PBCLR)+'__pi'+str(p)+'__pm'+str(p1)+'_L'+str(size_sys)+'_s'+str(seed)+ \
                '_nc'+str(n_clusters_pbc)+'_smc'+str(max_size_pbc)+'_n'+str(n_clusters_pbc)

                
                
            text_file1=open(filename1+'.txt', "w+")
            text_file1.write('Total number of cluster= '+ repr(n_clusters)+'\n')
            text_file1.write('Size of the largest cluster (number of site occupied)= '+ repr(max_size_pbc)+'\n')
            text_file1.write('Number of clusters with given size= ' +repr(sizes)+"\n")
            text_file1.close()
            data_pkl1 = {'cluster_pbc_int' : cluster_blank_pbc_int ,
                       'cluster_pbc_norm' : cluster_blank_pbc_norm,
                       'n_clusters_pbc':n_clusters_pbc,
                       'cluster_int':cluster_blank_int,
                       'cluster_norm':cluster_blank_norm,
                       'proba largest' : proba_largest,
                       'square proba':square_proba,
                       'size max cluster':max_size_pbc,
                       'pi':p,
                       'pf':p1,
                       'nb_vlines':nb_vlines,
                       'nb_hlines':nb_hlines,
                       'coord_hlines':coord_hlines,
                       'thick_hlines':thick_hlines,
                       'coord_vlines':coord_vlines,
                       'thick_vlines':thick_vlines}
            
            pkl_file1=open(filename1+'.pkl', "wb")
            pickle.dump(data_pkl1 ,pkl_file1)
            pkl_file1.close()
            
        
        else:    
            filename0='pc_0_0_'+str(HWTB)+'_'+str(HWLR)+'_'+str(PBCTB)+'_'+str(PBCLR)+'__pi'+str(p)+'__pm'+str(p1)+'_L'+str(size_sys)+'_s'+str(seed)+ \
                '_nc'+str(n_clusters_pbc)+'_smc'+str(max_size_pbc)+'_n'+str(n_clusters_pbc)


            text_file0=open(filename0+'.txt', "w+")
            text_file0.write('Total number of cluster= '+ repr(n_clusters_pbc)+'\n')
            text_file0.write('Size of the largest cluster (number of site occupied)= '+ repr(max_size_pbc)+'\n')
            text_file0.write('Sizes of each clusters (number associated to the cluster: number of occupied sites)= ' +repr(sizes)+"\n")
            text_file0.close()

            data_pkl0 = {'cluster_pbc_int' : cluster_blank_pbc_int ,
                       'cluster_pbc_norm' : cluster_blank_pbc_norm,
                       'n_clusters_pbc':n_clusters_pbc,
                       'cluster_int':cluster_blank_int,
                       'cluster_norm':cluster_blank_norm,
                       'proba largest' : proba_largest,
                       'square proba':square_proba,
                       'size max cluster':max_size_pbc,
                       'pi':p,
                       'pf':p1,
                       'nb_vlines':nb_vlines,
                       'nb_hlines':nb_hlines,
                       'coord_hlines':coord_hlines,
                       'thick_hlines':thick_hlines,
                       'coord_vlines':coord_vlines,
                       'thick_vlines':thick_vlines}
            
            pkl_file0=open(filename0+'.pkl', "wb")
            pickle.dump(data_pkl0 ,pkl_file0)
            pkl_file0.close()
            
        end2=time.time()-start2
        print(end2)

    return cluster,n_clusters,cluster_blank_pbc,n_clusters_pbc, sizes_pbc,lattice_para[0],new_mapping,order,order_pbc,occ,sizes,cluster_blank_int, top_bot_inter,sides_inter,cluster_blank_nan



#################################################################################################################################
def percolation_density(number_configs,perco_list,lattice_size,hlines,hthick,vlines,vthick,updlines,updthick,downdlines,downdthick,typemod):  
    import os
    
    import time
    
    dens=[]
    start1= time.time()
    configs_wanted=number_configs
    #seed=int(binascii.hexlify(os.urandom(4)),16)
    for p in perco_list:
        print('percolation_density: working on p=', p)

        configs_created=0
        
        if os.path.exists('p'+str(p)) and len(os.listdir('p'+str(p)))!=0:
            print('A directory '+'p='+str(p)+' already exists')
        else:
            create_directory('p'+str(p))
        
        os.chdir('p'+str(p))

        max_seed,seeds_existing,configs_existing=check_name('.')
        print('--- found seeds=', seeds_existing)

        if configs_wanted >= configs_existing:  #nbre_images:
            configs_tomake = configs_wanted - configs_existing   #nbre_images
            print('percolation_density: configs existing, wanted, tomake=',configs_existing, configs_wanted, configs_tomake)
            while configs_tomake > 0:
                seed=int(binascii.hexlify(os.urandom(4)),16)
                if seed in seeds_existing: #seed_list:
                    print('Image with seed = ',seed, 'already exists')
                    while seed in seeds_existing:
                        seed=int(binascii.hexlify(os.urandom(4)),16)
                    seeds_existing.append(seed)
                    print('--- NEW seed ', seed, ' scheduled to be made')
                    # now we have a good seed, let's percolate
                perco_calcul= percolation(1,p,lattice_size,seed,hlines,hthick,vlines,vthick,updlines,updthick,downdlines,downdthick,typemod)
                configs_created+=1
                configs_tomake-=1
                print('--- NEW configuration', seed,' was created')

            os.chdir('..')
            if configs_created!=0:
                print("-->",configs_created, 'new images were created')
        
    end1=time.time()
    total_time=end1-start1
    print("Images generated in : ", total_time, "seconds")
    return 

####################################################################################################################
#if ( len(sys.argv) == 8 ):
    #SEED = int(sys.argv[1])
lattice_size = 30# int(sys.argv[1])
perco_init = 1000#int(sys.argv[2]) 
perco_final = 9000#int(sys.argv[3])
perco_inc = 1000#int(sys.argv[4])
number_configs = 5#int(sys.argv[5])
hlines=1#int(sys.argv[6])
hthick=2#int(sys.argv[7])
vlines=2#int(sys.argv[8])
vthick=1#int(sys.argv[9])
updlines=1#int(sys.argv[10])
updthick=1#int(sys.argv[11])
downdlines=1#int(sys.argv[10])
downdthick=1#int(sys.argv[11])
typemod=-2#int(sys.argv[12])
 

    
print("perco_RandomCrosses:", lattice_size, perco_init,perco_final,perco_inc, number_configs)
perco_list=[val/10000 for val in range(perco_init,perco_final+1,perco_inc)]
    #print(range(perco_init,perco_final+1,perco_inc))
    #print(perco_list)
    
    # %%
percolation_density(number_configs,perco_list,lattice_size,hlines,hthick,vlines,vthick,updlines,updthick,downdlines,downdthick,typemod) 
    #1: number of images for a given p
    #2:list of p
    #3: side length of the square lattice
    #4: seed 
    
#else:
#    print ('Number of', len(sys.argv), \
#           'arguments is less than expected (6) --- ABORTING!')
#    print ('Usage: python '+sys.argv[0],\
#           '  size p_initial*10000 p_final*10000 dp*10000 number_of_configurations')
    #print ('Argument List:', str(sys.argv))        
    #return
# Out:
# --- NOT working on avon
#  --- working for phsht
# perco_RandomCrosses: 30 1000 9000 1000 5
# percolation_density: working on p= 0.1
# Successfully created the directory : p0.1
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 1183997996
# --- working in image 0 2022-06-29 16:38:09.729281
# lattice_config START 2022-06-29 16:38:09.729317
# lattice_config END 2022-06-29 16:38:09.729657
# occupied 90
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.730092
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.730965
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.730989
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.731617
# PBC characterization 2022-06-29 16:38:09.731639
# HW characterization 2022-06-29 16:38:09.731738
# PBC coloring 2022-06-29 16:38:09.732288
# n clusters pbc 75
# n clusters 76
# density change p= 0.1 -> 0.08
# max clus 4
# 0.00884389877319336
# --- NEW configuration 1183997996  was created
# percolation: new percolation starting with seed= 796354158
# --- working in image 0 2022-06-29 16:38:09.738509
# lattice_config START 2022-06-29 16:38:09.738542
# lattice_config END 2022-06-29 16:38:09.738728
# occupied 90
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.739264
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.740084
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.740108
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.740720
# PBC characterization 2022-06-29 16:38:09.740741
# HW characterization 2022-06-29 16:38:09.740826
# PBC coloring 2022-06-29 16:38:09.741359
# n clusters pbc 76
# n clusters 76
# density change p= 0.1 -> 0.09
# max clus 7
# 0.008764028549194336
# --- NEW configuration 796354158  was created
# percolation: new percolation starting with seed= 2042885749
# --- working in image 0 2022-06-29 16:38:09.747680
# lattice_config START 2022-06-29 16:38:09.747721
# lattice_config END 2022-06-29 16:38:09.748189
# occupied 90
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.748454
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.749284
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.749472
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.750090
# PBC characterization 2022-06-29 16:38:09.750110
# HW characterization 2022-06-29 16:38:09.750188
# PBC coloring 2022-06-29 16:38:09.750608
# n clusters pbc 70
# n clusters 70
# density change p= 0.1 -> 0.09
# max clus 4
# 0.008961915969848633
# --- NEW configuration 2042885749  was created
# percolation: new percolation starting with seed= 1879656109
# --- working in image 0 2022-06-29 16:38:09.757065
# lattice_config START 2022-06-29 16:38:09.757194
# lattice_config END 2022-06-29 16:38:09.757506
# occupied 90
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.757765
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.758590
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.758614
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.759451
# PBC characterization 2022-06-29 16:38:09.759480
# HW characterization 2022-06-29 16:38:09.759777
# PBC coloring 2022-06-29 16:38:09.759937
# n clusters pbc 69
# n clusters 71
# density change p= 0.1 -> 0.08333333333333333
# max clus 5
# 0.008728265762329102
# --- NEW configuration 1879656109  was created
# percolation: new percolation starting with seed= 1814978145
# --- working in image 0 2022-06-29 16:38:09.766227
# lattice_config START 2022-06-29 16:38:09.766406
# lattice_config END 2022-06-29 16:38:09.766588
# occupied 90
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.766975
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.767810
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.767833
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.768657
# PBC characterization 2022-06-29 16:38:09.768679
# HW characterization 2022-06-29 16:38:09.768954
# PBC coloring 2022-06-29 16:38:09.769111
# n clusters pbc 71
# n clusters 71
# density change p= 0.1 -> 0.08666666666666667
# max clus 4
# 0.00823831558227539
# --- NEW configuration 1814978145  was created
# --> 5 new images were created
# percolation_density: working on p= 0.2
# Successfully created the directory : p0.2
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 932063856
# --- working in image 0 2022-06-29 16:38:09.776597
# lattice_config START 2022-06-29 16:38:09.776632
# lattice_config END 2022-06-29 16:38:09.776984
# occupied 180
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.777450
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.779078
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.779101
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.780310
# PBC characterization 2022-06-29 16:38:09.780333
# HW characterization 2022-06-29 16:38:09.780786
# PBC coloring 2022-06-29 16:38:09.781000
# n clusters pbc 113
# n clusters 116
# density change p= 0.2 -> 0.17555555555555555
# max clus 7
# 0.010648965835571289
# --- NEW configuration 932063856  was created
# percolation: new percolation starting with seed= 3524889568
# --- working in image 0 2022-06-29 16:38:09.787658
# lattice_config START 2022-06-29 16:38:09.787692
# lattice_config END 2022-06-29 16:38:09.788248
# occupied 180
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.788524
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.790189
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.790213
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.791673
# PBC characterization 2022-06-29 16:38:09.791698
# HW characterization 2022-06-29 16:38:09.791792
# PBC coloring 2022-06-29 16:38:09.792107
# n clusters pbc 110
# n clusters 111
# density change p= 0.2 -> 0.1711111111111111
# max clus 6
# 0.010632514953613281
# --- NEW configuration 3524889568  was created
# percolation: new percolation starting with seed= 2423534342
# --- working in image 0 2022-06-29 16:38:09.798732
# lattice_config START 2022-06-29 16:38:09.798855
# lattice_config END 2022-06-29 16:38:09.799344
# occupied 180
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.799635
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.801247
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.801270
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.802669
# PBC characterization 2022-06-29 16:38:09.802691
# HW characterization 2022-06-29 16:38:09.802984
# PBC coloring 2022-06-29 16:38:09.803167
# n clusters pbc 119
# n clusters 124
# density change p= 0.2 -> 0.16555555555555557
# max clus 6
# 0.010153770446777344
# --- NEW configuration 2423534342  was created
# percolation: new percolation starting with seed= 4170245075
# --- working in image 0 2022-06-29 16:38:09.809358
# lattice_config START 2022-06-29 16:38:09.809391
# lattice_config END 2022-06-29 16:38:09.809734
# occupied 180
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.810215
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.811805
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.811829
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.813222
# PBC characterization 2022-06-29 16:38:09.813245
# HW characterization 2022-06-29 16:38:09.813530
# PBC coloring 2022-06-29 16:38:09.813701
# n clusters pbc 116
# n clusters 116
# density change p= 0.2 -> 0.16666666666666666
# max clus 6
# 0.010643482208251953
# --- NEW configuration 4170245075  was created
# percolation: new percolation starting with seed= 1556829466
# --- working in image 0 2022-06-29 16:38:09.820328
# lattice_config START 2022-06-29 16:38:09.820361
# lattice_config END 2022-06-29 16:38:09.820978
# occupied 180
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.821258
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.822873
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.822896
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.824299
# PBC characterization 2022-06-29 16:38:09.824322
# HW characterization 2022-06-29 16:38:09.824579
# PBC coloring 2022-06-29 16:38:09.824787
# n clusters pbc 99
# n clusters 101
# density change p= 0.2 -> 0.16666666666666666
# max clus 10
# 0.010788202285766602
# --- NEW configuration 1556829466  was created
# --> 5 new images were created
# percolation_density: working on p= 0.3
# Successfully created the directory : p0.3
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 932908417
# --- working in image 0 2022-06-29 16:38:09.833081
# lattice_config START 2022-06-29 16:38:09.833114
# lattice_config END 2022-06-29 16:38:09.833659
# occupied 270
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.834209
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.836644
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.836668
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.838656
# PBC characterization 2022-06-29 16:38:09.838801
# HW characterization 2022-06-29 16:38:09.838896
# PBC coloring 2022-06-29 16:38:09.839149
# n clusters pbc 116
# n clusters 121
# density change p= 0.3 -> 0.2588888888888889
# max clus 11
# 0.012169361114501953
# --- NEW configuration 932908417  was created
# percolation: new percolation starting with seed= 3092495936
# --- working in image 0 2022-06-29 16:38:09.845631
# lattice_config START 2022-06-29 16:38:09.845742
# lattice_config END 2022-06-29 16:38:09.846284
# occupied 270
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.846726
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.849078
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.849101
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.850823
# PBC characterization 2022-06-29 16:38:09.851161
# HW characterization 2022-06-29 16:38:09.851344
# PBC coloring 2022-06-29 16:38:09.851519
# n clusters pbc 111
# n clusters 114
# density change p= 0.3 -> 0.2477777777777778
# max clus 14
# 0.011988401412963867
# --- NEW configuration 3092495936  was created
# percolation: new percolation starting with seed= 119962060
# --- working in image 0 2022-06-29 16:38:09.858014
# lattice_config START 2022-06-29 16:38:09.858048
# lattice_config END 2022-06-29 16:38:09.858821
# occupied 270
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.859072
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.861605
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.861629
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.863516
# PBC characterization 2022-06-29 16:38:09.863539
# HW characterization 2022-06-29 16:38:09.863802
# PBC coloring 2022-06-29 16:38:09.864009
# n clusters pbc 121
# n clusters 122
# density change p= 0.3 -> 0.2688888888888889
# max clus 15
# 0.012396574020385742
# --- NEW configuration 119962060  was created
# percolation: new percolation starting with seed= 849738099
# --- working in image 0 2022-06-29 16:38:09.870739
# lattice_config START 2022-06-29 16:38:09.870968
# lattice_config END 2022-06-29 16:38:09.871518
# occupied 270
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.871881
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.874220
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.874244
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.876173
# PBC characterization 2022-06-29 16:38:09.876195
# HW characterization 2022-06-29 16:38:09.876455
# PBC coloring 2022-06-29 16:38:09.876667
# n clusters pbc 120
# n clusters 124
# density change p= 0.3 -> 0.2588888888888889
# max clus 12
# 0.011690855026245117
# --- NEW configuration 849738099  was created
# percolation: new percolation starting with seed= 4052701574
# --- working in image 0 2022-06-29 16:38:09.882954
# lattice_config START 2022-06-29 16:38:09.883188
# lattice_config END 2022-06-29 16:38:09.883738
# occupied 270
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.884027
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.886331
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.886576
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.888307
# PBC characterization 2022-06-29 16:38:09.888487
# HW characterization 2022-06-29 16:38:09.888595
# PBC coloring 2022-06-29 16:38:09.888829
# n clusters pbc 115
# n clusters 121
# density change p= 0.3 -> 0.24444444444444444
# max clus 12
# 0.011810779571533203
# --- NEW configuration 4052701574  was created
# --> 5 new images were created
# percolation_density: working on p= 0.4
# Successfully created the directory : p0.4
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 660578068
# --- working in image 0 2022-06-29 16:38:09.896938
# lattice_config START 2022-06-29 16:38:09.897040
# lattice_config END 2022-06-29 16:38:09.897797
# occupied 360
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.898233
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.901322
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.901346
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.903816
# PBC characterization 2022-06-29 16:38:09.903960
# HW characterization 2022-06-29 16:38:09.904052
# PBC coloring 2022-06-29 16:38:09.904317
# n clusters pbc 79
# n clusters 89
# density change p= 0.4 -> 0.3433333333333333
# max clus 64
# 0.014007091522216797
# --- NEW configuration 660578068  was created
# percolation: new percolation starting with seed= 504199504
# --- working in image 0 2022-06-29 16:38:09.911342
# lattice_config START 2022-06-29 16:38:09.911567
# lattice_config END 2022-06-29 16:38:09.912335
# occupied 360
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.912633
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.915925
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.915950
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.918393
# PBC characterization 2022-06-29 16:38:09.918538
# HW characterization 2022-06-29 16:38:09.918642
# PBC coloring 2022-06-29 16:38:09.918890
# n clusters pbc 105
# n clusters 112
# density change p= 0.4 -> 0.3377777777777778
# max clus 41
# 0.014116525650024414
# --- NEW configuration 504199504  was created
# percolation: new percolation starting with seed= 3445676222
# --- working in image 0 2022-06-29 16:38:09.926136
# lattice_config START 2022-06-29 16:38:09.926241
# lattice_config END 2022-06-29 16:38:09.927009
# occupied 360
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.927454
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.930600
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.930624
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.933159
# PBC characterization 2022-06-29 16:38:09.933184
# HW characterization 2022-06-29 16:38:09.933477
# PBC coloring 2022-06-29 16:38:09.933648
# n clusters pbc 98
# n clusters 104
# density change p= 0.4 -> 0.32
# max clus 39
# 0.014235258102416992
# --- NEW configuration 3445676222  was created
# percolation: new percolation starting with seed= 1438163999
# --- working in image 0 2022-06-29 16:38:09.940784
# lattice_config START 2022-06-29 16:38:09.941013
# lattice_config END 2022-06-29 16:38:09.941805
# occupied 360
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.942197
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.945282
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.945305
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.947777
# PBC characterization 2022-06-29 16:38:09.947800
# HW characterization 2022-06-29 16:38:09.948059
# PBC coloring 2022-06-29 16:38:09.948275
# n clusters pbc 100
# n clusters 109
# density change p= 0.4 -> 0.3322222222222222
# max clus 25
# 0.013639211654663086
# --- NEW configuration 1438163999  was created
# percolation: new percolation starting with seed= 2646523772
# --- working in image 0 2022-06-29 16:38:09.954950
# lattice_config START 2022-06-29 16:38:09.954983
# lattice_config END 2022-06-29 16:38:09.956012
# occupied 360
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.956323
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.959465
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.959489
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.962078
# PBC characterization 2022-06-29 16:38:09.962195
# HW characterization 2022-06-29 16:38:09.962279
# PBC coloring 2022-06-29 16:38:09.962514
# n clusters pbc 79
# n clusters 89
# density change p= 0.4 -> 0.33444444444444443
# max clus 35
# 0.014236927032470703
# --- NEW configuration 2646523772  was created
# --> 5 new images were created
# percolation_density: working on p= 0.5
# Successfully created the directory : p0.5
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 2168794264
# --- working in image 0 2022-06-29 16:38:09.971526
# lattice_config START 2022-06-29 16:38:09.971630
# lattice_config END 2022-06-29 16:38:09.972591
# occupied 450
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.973048
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.976921
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.976945
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.979770
# PBC characterization 2022-06-29 16:38:09.979792
# HW characterization 2022-06-29 16:38:09.980232
# PBC coloring 2022-06-29 16:38:09.980435
# n clusters pbc 60
# n clusters 73
# density change p= 0.5 -> 0.4266666666666667
# max clus 93
# 0.015559911727905273
# --- NEW configuration 2168794264  was created
# percolation: new percolation starting with seed= 2685305816
# --- working in image 0 2022-06-29 16:38:09.987481
# lattice_config START 2022-06-29 16:38:09.987709
# lattice_config END 2022-06-29 16:38:09.988713
# occupied 450
# Hoshen-Kopelman PBS START 2022-06-29 16:38:09.989110
# Hoshen-Kopelman PBC END 2022-06-29 16:38:09.992997
# Hoshen-Kopelman HW START 2022-06-29 16:38:09.993020
# Hoshen-Kopelman HW END 2022-06-29 16:38:09.995841
# PBC characterization 2022-06-29 16:38:09.995863
# HW characterization 2022-06-29 16:38:09.996305
# PBC coloring 2022-06-29 16:38:09.996459
# n clusters pbc 53
# n clusters 60
# density change p= 0.5 -> 0.42333333333333334
# max clus 215
# 0.01563739776611328
# --- NEW configuration 2685305816  was created
# percolation: new percolation starting with seed= 3330860836
# --- working in image 0 2022-06-29 16:38:10.003695
# lattice_config START 2022-06-29 16:38:10.003874
# lattice_config END 2022-06-29 16:38:10.005054
# occupied 450
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.005424
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.009331
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.009354
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.012412
# PBC characterization 2022-06-29 16:38:10.012435
# HW characterization 2022-06-29 16:38:10.012701
# PBC coloring 2022-06-29 16:38:10.012859
# n clusters pbc 58
# n clusters 73
# density change p= 0.5 -> 0.42777777777777776
# max clus 128
# 0.01599574089050293
# --- NEW configuration 3330860836  was created
# percolation: new percolation starting with seed= 2055538552
# --- working in image 0 2022-06-29 16:38:10.020238
# lattice_config START 2022-06-29 16:38:10.020273
# lattice_config END 2022-06-29 16:38:10.021305
# occupied 450
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.021818
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.025728
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.025754
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.028844
# PBC characterization 2022-06-29 16:38:10.028991
# HW characterization 2022-06-29 16:38:10.029152
# PBC coloring 2022-06-29 16:38:10.029312
# n clusters pbc 67
# n clusters 79
# density change p= 0.5 -> 0.4222222222222222
# max clus 85
# 0.016109466552734375
# --- NEW configuration 2055538552  was created
# percolation: new percolation starting with seed= 533860897
# --- working in image 0 2022-06-29 16:38:10.036684
# lattice_config START 2022-06-29 16:38:10.036717
# lattice_config END 2022-06-29 16:38:10.037715
# occupied 450
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.038336
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.042264
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.042290
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.045369
# PBC characterization 2022-06-29 16:38:10.045398
# HW characterization 2022-06-29 16:38:10.045686
# PBC coloring 2022-06-29 16:38:10.045848
# n clusters pbc 64
# n clusters 76
# density change p= 0.5 -> 0.4122222222222222
# max clus 166
# 0.01613926887512207
# --- NEW configuration 533860897  was created
# --> 5 new images were created
# percolation_density: working on p= 0.6
# Successfully created the directory : p0.6
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 3454361334
# --- working in image 0 2022-06-29 16:38:10.054776
# lattice_config START 2022-06-29 16:38:10.054898
# lattice_config END 2022-06-29 16:38:10.056356
# occupied 540
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.056712
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.061404
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.061431
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.064799
# PBC characterization 2022-06-29 16:38:10.065200
# HW characterization 2022-06-29 16:38:10.065368
# PBC coloring 2022-06-29 16:38:10.065537
# n clusters pbc 23
# n clusters 37
# density change p= 0.6 -> 0.5166666666666667
# max clus 296
# 0.018087387084960938
# --- NEW configuration 3454361334  was created
# percolation: new percolation starting with seed= 767228889
# --- working in image 0 2022-06-29 16:38:10.073673
# lattice_config START 2022-06-29 16:38:10.073782
# lattice_config END 2022-06-29 16:38:10.075258
# occupied 540
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.075774
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.080539
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.080802
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.084260
# PBC characterization 2022-06-29 16:38:10.084461
# HW characterization 2022-06-29 16:38:10.084615
# PBC coloring 2022-06-29 16:38:10.084759
# n clusters pbc 28
# n clusters 37
# density change p= 0.6 -> 0.5077777777777778
# max clus 394
# 0.018551349639892578
# --- NEW configuration 767228889  was created
# percolation: new percolation starting with seed= 3856682791
# --- working in image 0 2022-06-29 16:38:10.092772
# lattice_config START 2022-06-29 16:38:10.092896
# lattice_config END 2022-06-29 16:38:10.094204
# occupied 540
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.094656
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.099398
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.099421
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.102832
# PBC characterization 2022-06-29 16:38:10.102860
# HW characterization 2022-06-29 16:38:10.103401
# PBC coloring 2022-06-29 16:38:10.103455
# n clusters pbc 22
# n clusters 32
# density change p= 0.6 -> 0.49333333333333335
# max clus 509
# 0.017836809158325195
# --- NEW configuration 3856682791  was created
# percolation: new percolation starting with seed= 3648631266
# --- working in image 0 2022-06-29 16:38:10.111023
# lattice_config START 2022-06-29 16:38:10.111279
# lattice_config END 2022-06-29 16:38:10.112756
# occupied 540
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.113130
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.117842
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.117882
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.121986
# PBC characterization 2022-06-29 16:38:10.122017
# HW characterization 2022-06-29 16:38:10.122206
# PBC coloring 2022-06-29 16:38:10.122332
# n clusters pbc 24
# n clusters 36
# density change p= 0.6 -> 0.49444444444444446
# max clus 392
# 0.01921868324279785
# --- NEW configuration 3648631266  was created
# percolation: new percolation starting with seed= 3171280406
# --- working in image 0 2022-06-29 16:38:10.130881
# lattice_config START 2022-06-29 16:38:10.130914
# lattice_config END 2022-06-29 16:38:10.132444
# occupied 540
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.132791
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.137514
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.137544
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.140962
# PBC characterization 2022-06-29 16:38:10.140987
# HW characterization 2022-06-29 16:38:10.141465
# PBC coloring 2022-06-29 16:38:10.141609
# n clusters pbc 14
# n clusters 23
# density change p= 0.6 -> 0.5
# max clus 482
# 0.017908811569213867
# --- NEW configuration 3171280406  was created
# --> 5 new images were created
# percolation_density: working on p= 0.7
# Successfully created the directory : p0.7
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 3906857164
# --- working in image 0 2022-06-29 16:38:10.150555
# lattice_config START 2022-06-29 16:38:10.150700
# lattice_config END 2022-06-29 16:38:10.152510
# occupied 630
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.152994
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.158816
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.158845
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.162912
# PBC characterization 2022-06-29 16:38:10.163210
# HW characterization 2022-06-29 16:38:10.163276
# PBC coloring 2022-06-29 16:38:10.163317
# n clusters pbc 6
# n clusters 9
# density change p= 0.7 -> 0.5733333333333334
# max clus 624
# 0.019976139068603516
# --- NEW configuration 3906857164  was created
# percolation: new percolation starting with seed= 3315142406
# --- working in image 0 2022-06-29 16:38:10.171047
# lattice_config START 2022-06-29 16:38:10.171080
# lattice_config END 2022-06-29 16:38:10.173021
# occupied 630
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.173396
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.179173
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.179200
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.183433
# PBC characterization 2022-06-29 16:38:10.183459
# HW characterization 2022-06-29 16:38:10.183506
# PBC coloring 2022-06-29 16:38:10.183548
# n clusters pbc 9
# n clusters 21
# density change p= 0.7 -> 0.5688888888888889
# max clus 609
# 0.019826650619506836
# --- NEW configuration 3315142406  was created
# percolation: new percolation starting with seed= 161212283
# --- working in image 0 2022-06-29 16:38:10.191196
# lattice_config START 2022-06-29 16:38:10.191393
# lattice_config END 2022-06-29 16:38:10.193121
# occupied 630
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.193580
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.199396
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.199424
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.203748
# PBC characterization 2022-06-29 16:38:10.203797
# HW characterization 2022-06-29 16:38:10.203858
# PBC coloring 2022-06-29 16:38:10.204162
# n clusters pbc 9
# n clusters 17
# density change p= 0.7 -> 0.6
# max clus 621
# 0.020062923431396484
# --- NEW configuration 161212283  was created
# percolation: new percolation starting with seed= 2743005112
# --- working in image 0 2022-06-29 16:38:10.211849
# lattice_config START 2022-06-29 16:38:10.211884
# lattice_config END 2022-06-29 16:38:10.213724
# occupied 630
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.214099
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.219877
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.219997
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.224150
# PBC characterization 2022-06-29 16:38:10.224169
# HW characterization 2022-06-29 16:38:10.224207
# PBC coloring 2022-06-29 16:38:10.224249
# n clusters pbc 6
# n clusters 11
# density change p= 0.7 -> 0.5966666666666667
# max clus 618
# 0.01985764503479004
# --- NEW configuration 2743005112  was created
# percolation: new percolation starting with seed= 331988375
# --- working in image 0 2022-06-29 16:38:10.231838
# lattice_config START 2022-06-29 16:38:10.232253
# lattice_config END 2022-06-29 16:38:10.233933
# occupied 630
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.234416
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.240239
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.240264
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.244348
# PBC characterization 2022-06-29 16:38:10.244365
# HW characterization 2022-06-29 16:38:10.244402
# PBC coloring 2022-06-29 16:38:10.244859
# n clusters pbc 13
# n clusters 17
# density change p= 0.7 -> 0.6066666666666667
# max clus 612
# 0.020075082778930664
# --- NEW configuration 331988375  was created
# --> 5 new images were created
# percolation_density: working on p= 0.8
# Successfully created the directory : p0.8
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 712833696
# --- working in image 0 2022-06-29 16:38:10.254470
# lattice_config START 2022-06-29 16:38:10.254591
# lattice_config END 2022-06-29 16:38:10.256885
# occupied 720
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.257415
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.264215
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.264233
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.268940
# PBC characterization 2022-06-29 16:38:10.268956
# HW characterization 2022-06-29 16:38:10.268986
# PBC coloring 2022-06-29 16:38:10.269025
# n clusters pbc 1
# n clusters 1
# density change p= 0.8 -> 0.66
# max clus 720
# 0.022173166275024414
# --- NEW configuration 712833696  was created
# percolation: new percolation starting with seed= 3779649650
# --- working in image 0 2022-06-29 16:38:10.277083
# lattice_config START 2022-06-29 16:38:10.277287
# lattice_config END 2022-06-29 16:38:10.279495
# occupied 720
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.280025
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.286816
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.286951
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.291686
# PBC characterization 2022-06-29 16:38:10.291713
# HW characterization 2022-06-29 16:38:10.291759
# PBC coloring 2022-06-29 16:38:10.292413
# n clusters pbc 1
# n clusters 3
# density change p= 0.8 -> 0.6722222222222223
# max clus 720
# 0.023379087448120117
# --- NEW configuration 3779649650  was created
# percolation: new percolation starting with seed= 3496289145
# --- working in image 0 2022-06-29 16:38:10.300884
# lattice_config START 2022-06-29 16:38:10.301390
# lattice_config END 2022-06-29 16:38:10.303609
# occupied 720
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.304418
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.311259
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.311566
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.316300
# PBC characterization 2022-06-29 16:38:10.316627
# HW characterization 2022-06-29 16:38:10.316751
# PBC coloring 2022-06-29 16:38:10.316964
# n clusters pbc 1
# n clusters 1
# density change p= 0.8 -> 0.6911111111111111
# max clus 720
# 0.023871183395385742
# --- NEW configuration 3496289145  was created
# percolation: new percolation starting with seed= 4000456263
# --- working in image 0 2022-06-29 16:38:10.325378
# lattice_config START 2022-06-29 16:38:10.325409
# lattice_config END 2022-06-29 16:38:10.328601
# occupied 720
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.329363
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.336136
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.336168
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.340900
# PBC characterization 2022-06-29 16:38:10.340930
# HW characterization 2022-06-29 16:38:10.341080
# PBC coloring 2022-06-29 16:38:10.341121
# n clusters pbc 2
# n clusters 3
# density change p= 0.8 -> 0.6788888888888889
# max clus 719
# 0.024122238159179688
# --- NEW configuration 4000456263  was created
# percolation: new percolation starting with seed= 4169995023
# --- working in image 0 2022-06-29 16:38:10.349891
# lattice_config START 2022-06-29 16:38:10.350096
# lattice_config END 2022-06-29 16:38:10.352448
# occupied 720
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.353084
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.359894
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.359913
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.364642
# PBC characterization 2022-06-29 16:38:10.364666
# HW characterization 2022-06-29 16:38:10.364719
# PBC coloring 2022-06-29 16:38:10.365213
# n clusters pbc 2
# n clusters 5
# density change p= 0.8 -> 0.6722222222222223
# max clus 719
# 0.022778749465942383
# --- NEW configuration 4169995023  was created
# --> 5 new images were created
# percolation_density: working on p= 0.9
# Successfully created the directory : p0.9
# check: max_seed, nbre_file = 0 0
# --- found seeds= []
# percolation_density: configs existing, wanted, tomake= 0 5 5
# percolation: new percolation starting with seed= 207586445
# --- working in image 0 2022-06-29 16:38:10.374766
# lattice_config START 2022-06-29 16:38:10.374944
# lattice_config END 2022-06-29 16:38:10.378128
# occupied 810
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.378666
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.386496
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.386523
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.391640
# PBC characterization 2022-06-29 16:38:10.391655
# HW characterization 2022-06-29 16:38:10.391700
# PBC coloring 2022-06-29 16:38:10.392210
# n clusters pbc 1
# n clusters 1
# density change p= 0.9 -> 0.7711111111111111
# max clus 810
# 0.024965524673461914
# --- NEW configuration 207586445  was created
# percolation: new percolation starting with seed= 3925937285
# --- working in image 0 2022-06-29 16:38:10.400184
# lattice_config START 2022-06-29 16:38:10.400377
# lattice_config END 2022-06-29 16:38:10.403642
# occupied 810
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.404139
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.411966
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.412084
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.417497
# PBC characterization 2022-06-29 16:38:10.417610
# HW characterization 2022-06-29 16:38:10.417698
# PBC coloring 2022-06-29 16:38:10.417851
# n clusters pbc 1
# n clusters 1
# density change p= 0.9 -> 0.7333333333333333
# max clus 810
# 0.02500128746032715
# --- NEW configuration 3925937285  was created
# percolation: new percolation starting with seed= 598520909
# --- working in image 0 2022-06-29 16:38:10.425643
# lattice_config START 2022-06-29 16:38:10.425677
# lattice_config END 2022-06-29 16:38:10.428791
# occupied 810
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.429488
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.437146
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.437267
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.442579
# PBC characterization 2022-06-29 16:38:10.442690
# HW characterization 2022-06-29 16:38:10.442730
# PBC coloring 2022-06-29 16:38:10.442760
# n clusters pbc 1
# n clusters 1
# density change p= 0.9 -> 0.7811111111111111
# max clus 810
# 0.024814605712890625
# --- NEW configuration 598520909  was created
# percolation: new percolation starting with seed= 1690674768
# --- working in image 0 2022-06-29 16:38:10.450771
# lattice_config START 2022-06-29 16:38:10.450805
# lattice_config END 2022-06-29 16:38:10.454141
# occupied 810
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.454514
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.462321
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.462347
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.467822
# PBC characterization 2022-06-29 16:38:10.467839
# HW characterization 2022-06-29 16:38:10.467883
# PBC coloring 2022-06-29 16:38:10.468196
# n clusters pbc 1
# n clusters 2
# density change p= 0.9 -> 0.7555555555555555
# max clus 810
# 0.025205373764038086
# --- NEW configuration 1690674768  was created
# percolation: new percolation starting with seed= 1857706856
# --- working in image 0 2022-06-29 16:38:10.476284
# lattice_config START 2022-06-29 16:38:10.476316
# lattice_config END 2022-06-29 16:38:10.479786
# occupied 810
# Hoshen-Kopelman PBS START 2022-06-29 16:38:10.480105
# Hoshen-Kopelman PBC END 2022-06-29 16:38:10.488066
# Hoshen-Kopelman HW START 2022-06-29 16:38:10.488195
# Hoshen-Kopelman HW END 2022-06-29 16:38:10.493736
# PBC characterization 2022-06-29 16:38:10.493762
# HW characterization 2022-06-29 16:38:10.493802
# PBC coloring 2022-06-29 16:38:10.494070
# n clusters pbc 1
# n clusters 1
# density change p= 0.9 -> 0.7555555555555555
# max clus 810
# 0.024982213973999023
# --- NEW configuration 1857706856  was created
# --> 5 new images were created
# Images generated in :  0.7739436626434326 seconds
